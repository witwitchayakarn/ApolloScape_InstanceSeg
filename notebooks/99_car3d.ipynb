# %%
import os
import sys
import pickle
import yaml

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

import torch

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

scale = 1.8
plt.rcParams['figure.figsize'] = [6.4*scale, 4.8*scale]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
sys.path.append('/home/wit/Drive/Workspace/ApolloScape_InstanceSeg/lib')
from utils.transforms import RandomTransformPixels

# %%
transform = RandomTransformPixels()

# %%
#fname = 'ID_49988e11d'
#fname = 'ID_dfd1abfab'
fname = 'ID_bda236c87'
im = cv2.imread(f'../peku/train/images/{fname}.jpg')
im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
im_tran = np.array(transform(image=im_rgb, target=None)[0])
plt.imshow(im_tran)
